# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# This notebook explores relationships between passenger features and
# survival outcomes in the Titanic dataset using visualizations and summary statistics.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../EDA/cleaned_train.csv")

# %%
df.head()
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Survived           891 non-null    int64
#  1   Pclass             891 non-null    int64
#  2   Name               891 non-null    object
#  3   Sex                891 non-null    int64
#  4   Age                891 non-null    float64
#  5   SibSp              891 non-null    int64
#  6   Parch              891 non-null    int64
#  7   Fare               891 non-null    float64
#  8   Embarked_Q         891 non-null    bool
#  9   Embarked_S         891 non-null    bool
#  10  CabinDeck_B        891 non-null    bool
#  11  CabinDeck_C        891 non-null    bool
#  12  CabinDeck_D        891 non-null    bool
#  13  CabinDeck_E        891 non-null    bool
#  14  CabinDeck_F        891 non-null    bool
#  15  CabinDeck_G        891 non-null    bool
#  16  CabinDeck_T        891 non-null    bool
#  17  CabinDeck_Unknown  891 non-null    bool
# dtypes: bool(10), float64(2), int64(5), object(1)
# memory usage: 64.5+ KB
# Survived             0
# Pclass               0
# Name                 0
# Sex                  0
# Age                  0
# SibSp                0
# Parch                0
# Fare                 0
# Embarked_Q           0
# Embarked_S           0
# CabinDeck_B          0
# CabinDeck_C          0
# CabinDeck_D          0
# CabinDeck_E          0
# CabinDeck_F          0
# CabinDeck_G          0
# CabinDeck_T          0
# CabinDeck_Unknown    0
# dtype: int64

# %% [markdown]
# ## Plot 1 — Survival vs Gender

# %%
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Survival by Gender")
plt.show()

# %% [markdown]
# **Observation:**
# Female passengers had a significantly higher survival rate compared to male passengers.

# %% [markdown]
# ## Plot 2 — Survival vs Passenger Class

# %%
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title("Survival by Passenger Class")
plt.show()

# %% [markdown]
# **Observation:**
# Passengers in first class were more likely to survive than those in second and third class.

# %% [markdown]
# ## Plot 3 — Age distribution by survival

# %%
sns.histplot(data=df, x='Age', hue='Survived', bins=30, kde=True)
plt.title("Age Distribution by Survival")
plt.show()

# %% [markdown]
# **Observation:**
# Younger passengers, especially children, showed higher survival rates compared to older passengers.

# %% [markdown]
# ## Plot4 - Survival vs Fare

# %%
sns.histplot(data=df, x='Fare', hue='Survived', bins=30)
plt.title("Fare Distribution by Survival")
plt.show()

# %% [markdown]
# **Observation:**
# Passengers who paid higher fares generally had higher survival rates. This suggests that fare,
# which is correlated with passenger class and access to lifeboats, is an important factor in survival.

# %% [markdown]
# ## EDA Summary
#
# Exploratory Data Analysis revealed strong relationships between passenger survival and several
# features. Female passengers and those traveling in higher classes exhibited significantly higher
# survival rates. Age also played an important role, with younger passengers showing better survival
# outcomes. Additionally, passengers who paid higher fares were more likely to survive.
#
# These insights guided feature selection and engineering decisions for the predictive model.
